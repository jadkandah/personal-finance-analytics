# %%
import sys, os

# This makes Python see the project folder (the parent of notebooks/)
PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root added to sys.path:", PROJECT_ROOT)
# Out:
# Project root added to sys.path: /home/jad/personal-finance-analytics

# %%
from src.finance_pipeline import run

results = run(data_path="data/raw/private_data.csv", verbose=True)
results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.finance_pipeline import run
#       3 results = run(data_path="data/raw/private_data.csv", verbose=True)
#       4 results
#
# ModuleNotFoundError: No module named 'src.finance_pipeline'
